# %%
pip install bing_image_downloader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # import function downloader

# %%
from  bing_image_downloader import downloader

# %%
downloader.download("house" ,limit=30,output_dir="Dataset",adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\Admin\Music\4th sem  MANIKANDAN\dataset\Dataset\house
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Neely-Sieber_House%2C_front.jpg/1200px-Neely-Sieber_House%2C_front.jpg
# [Error]Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Neely-Sieber_House%2C_front.jpg/1200px-Neely-Sieber_House%2C_front.jpg
#
# [!] Issue getting: https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Neely-Sieber_House%2C_front.jpg/1200px-Neely-Sieber_House%2C_front.jpg
# [!] Error:: Invalid image, not saving https://upload.wikimedia.org/wikipedia/commons/thumb/4/45/Neely-Sieber_House%2C_front.jpg/1200px-Neely-Sieber_House%2C_front.jpg
#
# [%] Downloading Image #1 from https://upload.wikimedia.org/wikipedia/commons/thumb/0/0e/Claudehouse1.JPG/1200px-Claudehouse1.JPG
# [%] File Downloaded !
#
# ...

# %%
downloader.download("bike" ,limit=30,output_dir="Dataset",adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\Admin\Music\4th sem  MANIKANDAN\dataset\Dataset\bike
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://p.vitalmtb.com/photos/users/38191/setup_checks/31002/photos/49168/original_001.jpg?1453396172
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.drovercycles.co.uk/wp-content/uploads/2014/01/Absolute-Al.jpg
# [!] Issue getting: http://www.drovercycles.co.uk/wp-content/uploads/2014/01/Absolute-Al.jpg
# [!] Error:: HTTP Error 520:
# [%] Downloading Image #2 from http://wallpapercave.com/wp/wc1710311.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i5.walmartimages.com/asr/03e250d1-4204-4ac8-9e82-4d8aac82e200_1.a1d4bcc05375697b1071f51700281181.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://images6.alphacoders.com/549/549198.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("superbike" ,limit=30,output_dir="Dataset",adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\Admin\Music\4th sem  MANIKANDAN\dataset\Dataset\superbike
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 30 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://global.rk-japan.co.jp/wp-content/uploads/hi_AP1_1047_001_s.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.asphaltandrubber.com/wp-content/uploads/2011/02/Yamaha-World-Superbike-team-livery-Marco-Melandri-2011.jpg
# [!] Issue getting: http://www.asphaltandrubber.com/wp-content/uploads/2011/02/Yamaha-World-Superbike-team-livery-Marco-Melandri-2011.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1129)>
# [%] Downloading Image #2 from https://electricalcontractingnews.co.uk/wp-content/uploads/2016/11/Superbike.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.wallpaperup.com/uploads/wallpapers/2013/08/22/137968/ccfb4519b63ae7761d6a799e963bc700.jpg
# ...

# %%
downloader.download("birds" ,limit=30,output_dir="Dataset",adult_filter_off=True)
# Out:
# [%] Downloading Images to C:\Users\Admin\Music\4th sem  MANIKANDAN\dataset\Dataset\birds
#
#
# [!!]Indexing page: 1
#
# [%] No more images are available
#
#
# [%] Done. Downloaded 0 images.

# %%
import  os

# %%
import warnings

# %%
warnings.simplefilter('ignore')

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pip install scikit-image
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %%
mukesh = os.listdir("C:\\Users\\Admin\\Music\\4th sem  MANIKANDAN\\dataset\\Celebrity\\mukesh ambani")

# %%
Tata= os.listdir("C:\\Users\\Admin\\Music\\4th sem  MANIKANDAN\\dataset\\Celebrity\\ratan tata")

# %%
Sundar= os.listdir("C:\\Users\\Admin\\Music\\4th sem  MANIKANDAN\\dataset\\Celebrity\\sundarpichai")

# %%
limit = 10
mukesh_image=[None]*limit
j=0
for i in mukesh:
    if(j<limit):
        mukesh_image [j]=imread("C:\\Users\\Admin\\Music\\4th sem  MANIKANDAN\\dataset\\Celebrity\\mukesh ambani\\"+i)
        j+=1
    else:
        break

# %%
limit = 10
Tata_image=[None]*limit
j=0
for i in Tata:
    if(j<limit):
        Tata_image[j]=imread("C:\\Users\\Admin\\Music\\4th sem  MANIKANDAN\\dataset\\Celebrity\\ratan tata\\"+i)
        j+=1
    else:
        break

# %%
limit = 10
Sundar_image=[None]*limit
j=0
for i in Sundar:
    if(j<limit):
        Sundar_image[j]=imread("C:\\Users\\Admin\\Music\\4th sem  MANIKANDAN\\dataset\\Celebrity\\sundarpichai\\"+i)
        j+=1
    else:
        break

# %%
imshow(mukesh_image[3])

# %%
mukesh_gray=[None]*limit
j=0
for i in mukesh:
    if(j<limit):
        mukesh_gray[j]=rgb2gray(mukesh_image[j])
        j+=1
    else:
        break

# %%
Tata_gray=[None]*limit
j=0
for i in Tata:
    if(j<limit):
        Tata_gray[j]=rgb2gray(Tata_image[j])
        j+=1
    else:
        break

# %%
Sundar_gray=[None]*limit
j=0
for i in Sundar:
    if(j<limit):
        Sundar_image [j]=rgb2gray(Sundar_image[j][:,:,:3])
        j+=1
    else:
        break

# %%
for j in range (10):
    lm=mukesh_gray[j]
    mukesh_gray[j]=resize(lm,(512,512))

# %%
for j in range (10):
    pm=Tata_gray[j]
    Tata_gray[j]=resize(pm,(512,512))

# %%
for j in range (10):
    dp=Sundar_image[j]
    Sundar_gray[j]=resize(dp,(512,512))

# %%
mukesh_gray[0].shape
# Out:
# (512, 512)

# %%
imshow(mukesh_gray[0])

# %%
len_of_mukesh_image_image=len(mukesh_image)
len_of_mukesh_image_image
# Out:
# 10

# %%
image_size_mukesh=mukesh_gray[1].shape
image_size_mukesh
# Out:
# (512, 512)

# %%
flatten_size_mukesh=image_size_mukesh[0]*image_size_mukesh[1]
flatten_size_mukesh
# Out:
# 262144

# %%
for i in range(len_of_mukesh_image_image):
      mukesh_gray[i]=np.ndarray.flatten(mukesh_gray[i]).reshape(flatten_size_mukesh,1)

# %%
np.ndarray.flatten
# Out:
# <method 'flatten' of 'numpy.ndarray' objects>

# %%
mukesh_gray=np.dstack( mukesh_gray)

# %%
mukesh_gray
# Out:
# array([[[0.89307608, 0.55405159, 0.17218392, ..., 0.81659373,
#          0.84267822, 0.33484856]],
#
#        [[0.89307608, 0.55422242, 0.17218392, ..., 0.81659373,
#          0.84601558, 0.33198221]],
#
#        [[0.89307608, 0.55603756, 0.17219399, ..., 0.81659373,
#          0.84259732, 0.33099208]],
#
#        ...,
#
#        [[0.04348745, 0.0201834 , 0.44936324, ..., 0.08010588,
#          0.61800895, 0.23762474]],
#
#        [[0.04348745, 0.02017333, 0.49799714, ..., 0.08010588,
#          0.6114497 , 0.3146829 ]],
#
#        [[0.04348745, 0.02017333, 0.54328135, ..., 0.08010588,
#          0.61774622, 0.35370957]]])

# %%
mukesh_gray.shape
# Out:
# (262144, 1, 10)

# %%
mukesh_gray=np.rollaxis(mukesh_gray,axis=2,start=0)
mukesh_gray.shape
# Out:
# (10, 262144, 1)

# %%
mukesh_gray=mukesh_gray.reshape(len_of_mukesh_image_image,flatten_size_mukesh)
mukesh_gray.shape
# Out:
# (10, 262144)

# %%
mukesh_data=pd.DataFrame(mukesh_gray)

# %%
mukesh_data
# Out:
#      0         1         2         3         4         5         6       \
# 0  0.893076  0.893076  0.893076  0.893076  0.893076  0.893076  0.893076
# 1  0.554052  0.554222  0.556038  0.555993  0.554161  0.553502  0.547552
# 2  0.172184  0.172184  0.172194  0.174618  0.176105  0.176105  0.176105
# 3  0.193406  0.194025  0.197316  0.198843  0.202557  0.197690  0.197596
# 4  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 5  0.036458  0.047391  0.050722  0.046577  0.044069  0.048505  0.045609
# 6  0.878476  0.878476  0.877135  0.874579  0.874555  0.874826  0.877001
# 7  0.816594  0.816594  0.816594  0.816594  0.816594  0.816594  0.816594
# 8  0.842678  0.846016  0.842597  0.836867  0.844867  0.845828  0.841166
# 9  0.334849  0.331982  0.330992  0.330992  0.330967  0.330509  0.330482
#
#      7         8         9       ...    262134    262135    262136    262137  \
# 0  0.893076  0.893076  0.893076  ...  0.043487  0.043487  0.043487  0.043487
# ...

# %%
mukesh_data["Label"]="mukesh"
mukesh_data
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.893076  0.893076  0.893076  0.893076  0.893076  0.893076  0.893076
# 1  0.554052  0.554222  0.556038  0.555993  0.554161  0.553502  0.547552
# 2  0.172184  0.172184  0.172194  0.174618  0.176105  0.176105  0.176105
# 3  0.193406  0.194025  0.197316  0.198843  0.202557  0.197690  0.197596
# 4  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078  0.996078
# 5  0.036458  0.047391  0.050722  0.046577  0.044069  0.048505  0.045609
# 6  0.878476  0.878476  0.877135  0.874579  0.874555  0.874826  0.877001
# 7  0.816594  0.816594  0.816594  0.816594  0.816594  0.816594  0.816594
# 8  0.842678  0.846016  0.842597  0.836867  0.844867  0.845828  0.841166
# 9  0.334849  0.331982  0.330992  0.330992  0.330967  0.330509  0.330482
#
#           7         8         9  ...    262135    262136    262137    262138  \
# 0  0.893076  0.893076  0.893076  ...  0.043487  0.043487  0.043487  0.043487
# ...

# %% [markdown]
# # FOR Tata

# %%
len_of_img_Tata=len(Tata_gray)
len_of_img_Tata
# Out:
# 10

# %%
image_size_Tata=Tata_gray[1].shape
image_size_Tata
# Out:
# (512, 512)

# %%
flatten_size_Tata=image_size_Tata[0]*image_size_Tata[1]
flatten_size_Tata
# Out:
# 262144

# %%
for i in range(len_of_mukesh_image_image_Tata):
    Tata_gray[i]=np.ndarray.flatten(Tata_gray[i]).reshape(flatten_size_Tata,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 for i in range(len_of_mukesh_image_image_Tata):
#       2     Tata_gray[i]=np.ndarray.flatten(Tata_gray[i]).reshape(flatten_size_Tata,1)
#
# NameError: name 'len_of_mukesh_image_image_Tata' is not defined

# %%
np.ndarray.flatten
# Out:
# <method 'flatten' of 'numpy.ndarray' objects>

# %%
Tata_gray=np.dstack(Tata_gray)
Tata_gray
# Out:
# array([[[0.72518527, 0.45006029, 0.30811125, ..., 0.68787213,
#          0.45528835, 0.29253739],
#         [0.72647539, 0.46499398, 0.32041927, ..., 0.66556167,
#          0.46469586, 0.29596613],
#         [0.72761794, 0.47657032, 0.32184854, ..., 0.65577552,
#          0.46042333, 0.29772538],
#         ...,
#         [0.75609569, 0.68212644, 0.42469396, ..., 0.49976403,
#          0.68769496, 0.41938471],
#         [0.75609569, 0.67579625, 0.42912823, ..., 0.50514324,
#          0.690135  , 0.41938471],
#         [0.75609569, 0.66086257, 0.43492922, ..., 0.50140549,
#          0.69014093, 0.41938471]],
#
#        [[0.72140492, 0.46814195, 0.31579076, ..., 0.68601194,
#          0.45528835, 0.292282  ],
#         [0.72157869, 0.47609825, 0.32546971, ..., 0.66466338,
#          0.46469586, 0.29376049],
#         [0.72112284, 0.48400862, 0.31959719, ..., 0.65572497,
#          0.46042333, 0.29644843],
#         ...,
#         [0.75609569, 0.67849592, 0.42721791, ..., 0.50082457,
# ...

# %%
Tata_gray.shape
# Out:
# (512, 512, 10)

# %%
Tata_gray=np.rollaxis(Tata_gray,axis=2,start=0)
Tata_gray.shape
# Out:
# (10, 512, 512)

# %%
Tata_gray=Tata_gray.reshape(mukesh_image_Tata,flatten_size_Tata)
Tata_gray.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 Tata_gray=Tata_gray.reshape(mukesh_image_Tata,flatten_size_Tata)
#       2 Tata_gray.shape
#
# NameError: name 'mukesh_image_Tata' is not defined

# %%
Tata_data=pd.DataFrame(Tata_gray)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 Tata_data=pd.DataFrame(Tata_gray)
#
# File ~\anaconda3\envs\foundationofAI\lib\site-packages\pandas\core\frame.py:785, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     774         mgr = dict_to_mgr(
#     775             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     776             # attribute "name"
#    (...)
#     782             copy=_copy,
#     783         )
#     784     else:
# --> 785         mgr = ndarray_to_mgr(
#     786             data,
#     787             index,
#     788             columns,
#     789             dtype=dtype,
#     790             copy=copy,
#     791             typ=manager,
#     792         )
#     794 # For data is list-like, or Iterable (will consume into list)
#     795 elif is_list_like(data):
#
# ...

# %%
Tata_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 Tata_data
#
# NameError: name 'Tata_data' is not defined

# %%
Tata_data["Label"]="Tata"
Tata_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 Tata_data["Label"]="Tata"
#       2 Tata_data
#
# NameError: name 'Tata_data' is not defined

# %% [markdown]
# # For Sundar

# %%
mukesh_of_img_Sundar=mukesh(Sundar_gray)
mukesh_of_img_Sundar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 mukesh_of_img_Sundar=mukesh(Sundar_gray)
#       2 mukesh_of_img_Sundar
#
# TypeError: 'list' object is not callable

# %%
img_size_Sundar=Sundar_gray[1].shape
img_size_Sundar

# %%
flatten_size_Sundar=img_size_Sundar[0]*img_size_Sundar[1]
flatten_size_Sundar

# %%
for i in range(mukesh_of_img_Sundar):
    Sundar_gray[i]=np.ndarray.flatten(Sundar_gray[i]).reshape(flatten_size_Sundar,1)

# %%
np.ndarray.flatten

# %%
Sundar_gray=np.dstack(Sundar_gray)
Sundar_gray

# %%
Sundar_gray.shape

# %%
Sundar_gray=np.rollaxis(Sundar_gray,axis=2,start=0)
Sundar_gray.shape

# %%
Sundar_gray=Sundar_gray.reshape(mukesh_of_img_Sundar,flatten_size_Sundar)
Sundar_gray.shape

# %%
Sundar_data=pd.DataFrame(Sundar_gray)

# %%
Sundar_data

# %%
Sundar_data["Label"]="Sundar"
Sundar_data

# %% [markdown]
# # Merge Imgs

# %%
man_1=pd.concat([mukesh_data,Tata_data])

# %%
man=pd.concat([man_1,Sundar_data])

# %%
 man

# %% [markdown]
# # Shuffling

# %%
from sklearn.utils import shuffle

# %%
fb_indexed=shuffle(man).reset_index()
fb_indexed

# %%
fb_man=fb_indexed.drop(['index'],axis=1)

# %%
fb_man.to_csv("Players.csv")

# %%
x = fb_man.values[:,:-1]

# %%
y = fb_man.values[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape

# %%
x_test.shape

# %% [markdown]
# # Decomposition

# %%
from sklearn import decomposition

# %%
pca = decomposition.PCA(n_components=20, whiten=True, random_state=1)

# %% [markdown]
# # D5 Fitting Training Set

# %%
pca.fit(x_train)

# %%
y_train_pca = pca.transform(x_train)
y_test_pca = pca.transform(x_test)

# %%
y_train_pca.shape

# %%
y_test_pca.shape

# %% [markdown]
# # D7- viewing the priciple components or eigen faces

# %%
eigen = (np.reshape(x[10],(512,512)).astype(np.float64))

# %%
eigen

# %% [markdown]
# # D7.2 plotting

# %%
fig = plt.figure(figsize=(30,30))
for i in range(10):
    ax = fig.add_subplot(2, 5, i+1, xticks=[], yticks=[])
    ax.imshow(pca.components_[i].reshape(eigen.shape),cmap=plt.cm.bone)

# %% [markdown]
# # E-2 Support vector Machine Implementation

# %%
from sklearn import svm

# %%
clf = svm.SVC(C=2, gamma=0.006, kernel='rbf')
clf.fit(x_train_pca, y_train)

# %% [markdown]
# # F-1- Image Prediction

# %%
y_predict = clf.predict(x_test_pca)

# %%
y_predict

# %%
for i in (np.random.randint(0,6,6)):
    predicted_images = (np.reshape(x_test[i], (512,512)).astype(np.float64))
    plt.title('predicted label: {0}'. format(y_predict[i]))
    plt.imshow(predicted_images,interpolation = 'nearest',cmap= 'gray')
    plt.show()

# %%
from sklearn import metrics

# %%
accuracy=metrics.accuracy_score(y_test,y_predict)

# %%
accuracy
